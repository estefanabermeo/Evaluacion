# %% [markdown]
# <a href="https://colab.research.google.com/github/estefanabermeo/Evaluacion/blob/main/Evaluacion_Pt3_Espa%C3%B1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EVALUACIÓN PARTE 3 GIRONA ESPAÑA**
# #### Estefana Bermeo Severiano
# #### A01367558

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 3.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post4-py3-none-any.whl size=2973 sha256=4ffea43dd3f28642f9e11965d4b66489630b90a6c6cfcc478998f60c63218404
#   Stored in directory: /root/.cache/pip/wheels/46/b8/69/4f7789b7d2fc0718a44cbc4ae5d40970a40c22c472ae50f0a1
# Successfully built sklearn
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ...

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Carga desde un archivo .csv sin indice
esp= pd.read_csv("espana_limpio.csv", encoding = 'unicode_escape')
# Out:
# <ipython-input-3-60ef18748408>:2: DtypeWarning: Columns (0,2,8,24,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   esp= pd.read_csv("espana_limpio.csv", encoding = 'unicode_escape')

# %%
#Verificamos información del DataFrame
esp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19656 entries, 0 to 19655
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            19656 non-null  object
#  1   listing_url                                   19656 non-null  object
#  2   scrape_id                                     19656 non-null  object
#  3   last_scraped                                  19656 non-null  object
#  4   source                                        19656 non-null  object
#  5   name                                          19656 non-null  object
#  6   description                                   19656 non-null  object
#  7   picture_url                                   19656 non-null  object
#  8   host_id                                       19656 non-null  object
# ...

# %%
#Imprimo los primeros 5 registro del dataframe
esp.head()
# Out:
#         id                           listing_url scrape_id last_scraped  \
# 0    14551    https://www.airbnb.com/rooms/14551  2.02E+13     31/03/23
# 1  1205757  https://www.airbnb.com/rooms/1205757  2.02E+13     31/03/23
# 2  1212820  https://www.airbnb.com/rooms/1212820  2.02E+13     01/04/23
# 3   751638   https://www.airbnb.com/rooms/751638  2.02E+13     31/03/23
# 4    41342    https://www.airbnb.com/rooms/41342  2.02E+13     01/04/23
#
#             source                                      name  \
# 0      city scrape  Cozy & Colorful by Nature (Private Room)
# 1      city scrape   HabitaciÃÂ³n doble + baÃÂ±o y terraza
# 2      city scrape       Apartment port de rei stunning wiew
# 3      city scrape     Room Limon - Casa Pati de lÃÂ´Albera
# 4  previous scrape         Beachfront Tamariua (Costa Brava)
#
#                                          description  \
# 0  Up in the hill of MontjuÃÂ¯c (a mountain over...
# 1  <b>The space</b><br />HabitaciÃÂ³n confortabl...
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(esp)
# Out:
#                          id  frequency  percentage  cumulative_perc
# 0      666000000000000000.0         95    0.004833         0.004833
# 1      843000000000000000.0         78    0.003968         0.008801
# 2      811000000000000000.0         67    0.003409         0.012210
# 3      846000000000000000.0         59    0.003002         0.015212
# 4      853000000000000000.0         57    0.002900         0.018112
# ...                     ...        ...         ...              ...
# 14630              20826501          1    0.000051         0.999796
# 14631              21322462          1    0.000051         0.999847
# 14632              21653451          1    0.000051         0.999898
# 14633              21328892          1    0.000051         0.999949
# 14634              30388765          1    0.000051         1.000000
#
# [14635 rows x 4 columns]
#
# ----------------------------------------------------------------
#
# ...

# %% [markdown]
# ## **Variable 1: host_response_time**

# %%
var1= freq_tbl(esp['host_response_time'])
var1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      12261    0.623779         0.623811
# 1  within a few hours       2699    0.137312         0.761129
# 2        within a day       2188    0.111315         0.872450
# 3                  --       2088    0.106227         0.978682
# 4  a few days or more        418    0.021266         0.999949
# 5             4 baths          1    0.000051         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes 
Filtro= var1[var1['frequency']>100]
Filtro
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      12261    0.623779         0.623811
# 1  within a few hours       2699    0.137312         0.761129
# 2        within a day       2188    0.111315         0.872450
# 3                  --       2088    0.106227         0.978682
# 4  a few days or more        418    0.021266         0.999949

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('host_response_time')
Filtro_index
# Out:
#                     frequency  percentage  cumulative_perc
# host_response_time
# within an hour          12261    0.623779         0.623811
# within a few hours       2699    0.137312         0.761129
# within a day             2188    0.111315         0.872450
# --                       2088    0.106227         0.978682
# a few days or more        418    0.021266         0.999949

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Host Response Time')
plt.xlabel('Time')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## **Variable 2: host_acceptance_rate**

# %%
var2= freq_tbl(esp['host_acceptance_rate'])
var2
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                  100%       7477    0.380393         0.380412
# 1                   99%       2221    0.112993         0.493411
# 2                    0%       1560    0.079365         0.572780
# 3                   98%       1049    0.053368         0.626151
# 4                   96%        753    0.038309         0.664462
# ..                  ...        ...         ...              ...
# 87                6000%          1    0.000051         0.999796
# 88                   7%          1    0.000051         0.999847
# 89                   8%          1    0.000051         0.999898
# 90                  21%          1    0.000051         0.999949
# 91                  23%          1    0.000051         1.000000
#
# [92 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes 
Filtro2= var2[var2['frequency']>500]
Filtro2
# Out:
#   host_acceptance_rate  frequency  percentage  cumulative_perc
# 0                 100%       7477    0.380393         0.380412
# 1                  99%       2221    0.112993         0.493411
# 2                   0%       1560    0.079365         0.572780
# 3                  98%       1049    0.053368         0.626151
# 4                  96%        753    0.038309         0.664462
# 5                  97%        735    0.037393         0.701857
# 6                  91%        518    0.026353         0.728212

# %%
#Ajusto el indice de mi dataframe
Filtro_index2= Filtro2.set_index('host_acceptance_rate')
Filtro_index2
# Out:
#                       frequency  percentage  cumulative_perc
# host_acceptance_rate
# 100%                       7477    0.380393         0.380412
# 99%                        2221    0.112993         0.493411
# 0%                         1560    0.079365         0.572780
# 98%                        1049    0.053368         0.626151
# 96%                         753    0.038309         0.664462
# 97%                         735    0.037393         0.701857
# 91%                         518    0.026353         0.728212

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index2.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Host Acceptance Rate')
plt.xlabel('Rate')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index2["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## **Variable 3: host_identity_verified**

# %%
var3= freq_tbl(esp['host_identity_verified'])
var3
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      17276    0.878917         0.878962
# 1                      f       2261    0.115028         0.993996
# 2                     --        117    0.005952         0.999949
# 3               17/09/22          1    0.000051         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes 
Filtro3= var3[var3['frequency']>1]
Filtro3
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      17276    0.878917         0.878962
# 1                      f       2261    0.115028         0.993996
# 2                     --        117    0.005952         0.999949

# %%
#Ajusto el indice de mi dataframe
Filtro_index3= Filtro3.set_index('host_identity_verified')
Filtro_index3
# Out:
#                         frequency  percentage  cumulative_perc
# host_identity_verified
# t                           17276    0.878917         0.878962
# f                            2261    0.115028         0.993996
# --                            117    0.005952         0.999949

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index3.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Host Idenity Verified')
plt.xlabel('Identity Verified')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index3["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## **Variable 4: property_type**

# %%
var4= freq_tbl(esp['property_type'])
var4
# Out:
#                                         property_type  frequency  percentage  \
# 0                                  Entire rental unit       9339    0.475122
# 1                                         Entire home       3703    0.188390
# 2                                        Entire villa       1714    0.087200
# 3                                        Entire condo       1400    0.071225
# 4                                      Entire cottage        549    0.027930
# ..                                                ...        ...         ...
# 73                       Private room in earthen home          1    0.000051
# 74                                Private room in hut          1    0.000051
# 75  The closest beach (Sa Riera) is formed by the ...          1    0.000051
# 76                              Private room in cabin          1    0.000051
# 77                          Private room in treehouse          1    0.000051
#
#     cumulative_perc
# 0          0.475146
# ...

# %%
#Obtengo un filtro de los valores más reelevantes 
Filtro4= var4[var4['frequency']>400]
Filtro4
# Out:
#         property_type  frequency  percentage  cumulative_perc
# 0  Entire rental unit       9339    0.475122         0.475146
# 1         Entire home       3703    0.188390         0.663546
# 2        Entire villa       1714    0.087200         0.750750
# 3        Entire condo       1400    0.071225         0.821979
# 4      Entire cottage        549    0.027930         0.849911
# 5    Entire townhouse        453    0.023046         0.872959

# %%
#Ajusto el indice de mi dataframe
Filtro_index4= Filtro4.set_index('property_type')
Filtro_index4
# Out:
#                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit       9339    0.475122         0.475146
# Entire home              3703    0.188390         0.663546
# Entire villa             1714    0.087200         0.750750
# Entire condo             1400    0.071225         0.821979
# Entire cottage            549    0.027930         0.849911
# Entire townhouse          453    0.023046         0.872959

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index4.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Property Type')
plt.xlabel('Type')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index4["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## **Variable 5: bathrooms_text**

# %%
var5= freq_tbl(esp['bathrooms_text'])
var5
# Out:
#       bathrooms_text  frequency  percentage  cumulative_perc
# 0             1 bath       9648    0.490842         0.490867
# 1            2 baths       4618    0.234941         0.725820
# 2            3 baths       1245    0.063339         0.789163
# 3          1.5 baths       1180    0.060033         0.849199
# 4          2.5 baths        648    0.032967         0.882167
# 5     1 private bath        564    0.028694         0.910862
# 6            4 baths        432    0.021978         0.932842
# 7          3.5 baths        260    0.013228         0.946070
# 8      1 shared bath        252    0.012821         0.958891
# 9            5 baths        159    0.008089         0.966980
# 10         4.5 baths        133    0.006766         0.973747
# 11           6 baths         78    0.003968         0.977716
# 12  1.5 shared baths         76    0.003867         0.981582
# 13         5.5 baths         53    0.002696         0.984279
# ...

# %%
#Obtengo un filtro de los valores más reelevantes 
Filtro5= var5[var5['frequency']>400]
Filtro5
# Out:
#    bathrooms_text  frequency  percentage  cumulative_perc
# 0          1 bath       9648    0.490842         0.490867
# 1         2 baths       4618    0.234941         0.725820
# 2         3 baths       1245    0.063339         0.789163
# 3       1.5 baths       1180    0.060033         0.849199
# 4       2.5 baths        648    0.032967         0.882167
# 5  1 private bath        564    0.028694         0.910862
# 6         4 baths        432    0.021978         0.932842

# %%
#Ajusto el indice de mi dataframe
Filtro_index5= Filtro5.set_index('bathrooms_text')
Filtro_index5
# Out:
#                 frequency  percentage  cumulative_perc
# bathrooms_text
# 1 bath               9648    0.490842         0.490867
# 2 baths              4618    0.234941         0.725820
# 3 baths              1245    0.063339         0.789163
# 1.5 baths            1180    0.060033         0.849199
# 2.5 baths             648    0.032967         0.882167
# 1 private bath        564    0.028694         0.910862
# 4 baths               432    0.021978         0.932842

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index5.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Bathrooms')
plt.xlabel('Bathrooms')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index5["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
