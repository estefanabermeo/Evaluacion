# %% [markdown]
# <a href="https://colab.research.google.com/github/estefanabermeo/Evaluacion/blob/main/Evaluaci%C3%B3n_Pt1_Mexico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EVALUACIÓN PARTE 1 DF MÉXICO**
# #### Estefana Bermeo Severiano
# #### A01367558

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .csv
mexico = pd.read_csv('DF_Mexico.csv')
mexico.head(5)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  2056638  https://www.airbnb.com/rooms/2056638  20230329041210   2023-03-30
# 1  2072354  https://www.airbnb.com/rooms/2072354  20230329041210   2023-03-30
# 2   696037   https://www.airbnb.com/rooms/696037  20230329041210   2023-03-29
# 3    35797    https://www.airbnb.com/rooms/35797  20230329041210   2023-03-29
# 4    44616    https://www.airbnb.com/rooms/44616  20230329041210   2023-03-30
#
#         source                                               name  \
# 0  city scrape                 Amplio y luminoso loft en Coyoacán
# 1  city scrape                 Coyoacan Historic Studio Apartment
# 2  city scrape  3 Bedrooms, 2 blocks from Polanco - ALL RENOVA...
# 3  city scrape                                        Villa Dante
# 4  city scrape                                  CONDESA HAUS  B&B
#
#                                          description  \
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=mexico.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3596
# Length: 75, dtype: int64

# %%
valores_nulos.to_csv("valores_nulosmx.csv")

# %%
#Identificar valores nulos por dataframe
valores_nulostot=mexico.isnull().sum().sum()
valores_nulostot
# Out:
# 189609

# %%
#Elimino columnas que tienen todas las filas vacías
mexico.drop(["neighbourhood_group_cleansed", "bathrooms", "calendar_updated"], axis=1)
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %% [markdown]
# Para las columnas con **datos cualitativos** reemplazaré los valores nulos por strings en concretos que sean coherentes al contexto del atributo.

# %%
mexico["description"] = mexico["description"].fillna("Sin descripción") 
mexico["neiborhood_overview"] = mexico["neighborhood_overview"].fillna("Sin información")
mexico["host_name"] = mexico["host_name"].fillna("Anónimo")
mexico["host_since"] = mexico["host_since"].fillna("Sin fecha")
mexico["host_location"] = mexico["host_location"].fillna("Sin ubicación")
mexico["host_about"] = mexico["host_about"].fillna("Sin información")
mexico["host_response_time"] = mexico["host_response_time"].fillna("Sin información")
mexico["host_is_superhost"] = mexico["host_is_superhost"].fillna("Sin información")
mexico["host_thumbnail_url"] = mexico["host_thumbnail_url"].fillna("Sin url")
mexico["host_picture_url"] = mexico["host_picture_url"].fillna("Sin url")
mexico["host_thumbnail_url"] = mexico["host_thumbnail_url"].fillna("Sin información")
mexico["host_has_profile_pic"] = mexico["host_has_profile_pic"].fillna("Sin información")
mexico["host_identity_verified"] = mexico["host_identity_verified"].fillna("Sin información")
mexico["neighbourhood"] = mexico["neighbourhood"].fillna("Sin ubicación")
mexico["bathrooms_text"] = mexico["bathrooms_text"].fillna("Sin información")
mexico["first_review"] = mexico["first_review"].fillna("Sin fecha")
mexico["last_review"] = mexico["last_review"].fillna("Sin fecha")
mexico["license"] = mexico["license"].fillna("Sin licencia")
mexico["host_response_rate"] = mexico["host_response_rate"].fillna("0%")
mexico["host_acceptance_rate"] = mexico["host_acceptance_rate"].fillna("0%")

# %% [markdown]
# Para las columnas con **datos cuantitativos** remplazaré los valores nulos por 0 para no alterar los resultados y el análisis de este.

# %%
mexico = mexico.fillna(0)

# %%
#Corroboramos valores nulos en las columnas
valores_nulos = mexico.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# neiborhood_overview                             0
# Length: 76, dtype: int64

# %%
#Corroboramos valores nulos por dataframe
valores_nulos=mexico.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %% [markdown]
# ### **Eliminar Outliers**

# %%
#Instalamos librería para análisis de variables categóricas
# !pip install funpymodeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 4.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post4-py3-none-any.whl size=2973 sha256=b1457c918bcf7091717f5205eb757d73216044b9df49faa4e0f19d3ef74a8fdb
#   Stored in directory: /root/.cache/pip/wheels/46/b8/69/4f7789b7d2fc0718a44cbc4ae5d40970a40c22c472ae50f0a1
# Successfully built sklearn
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ...

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
from seaborn import load_dataset
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Separamos temporalmente las columnas cualitativas para llevar a cabo la eliminación de outliers de las columnas cuantitativas
mexico_num=mexico.drop(['id','listing_url','scrape_id','bedrooms','last_scraped','source','name','description', 'picture_url','host_id','host_url','host_name','host_since','host_location','host_about','host_response_time','host_response_rate','host_is_superhost', 'host_thumbnail_url','host_picture_url','host_neighbourhood','host_total_listings_count','host_verifications', 'host_has_profile_pic', 'host_identity_verified','neighbourhood','neighbourhood_cleansed','neighbourhood_group_cleansed','property_type','room_type','bathrooms_text','amenities','has_availability','calendar_last_scraped','first_review','last_review','license','instant_bookable',], axis=1)
mexico_num
# Out:
#                                    neighborhood_overview host_acceptance_rate  \
# 0                                                      0                   0%
# 1      Located in Coyoacan, in a quiet neighborhood w...                   0%
# 2      This area is called Nuevo Polanco, it has bein...                  90%
# 3      Centro comercial Santa Fe, parque interlomas y...                   0%
# 4                                                      0                  86%
# ...                                                  ...                  ...
# 24219                                                  0                 100%
# 24220                                                  0                   0%
# 24221                                                  0                  96%
# 24222                                                  0                 100%
# 24223  Una zona muy bonita ya que varias de las atrac...                 100%
#
# ...

# %%
mexico_cuali=mexico.drop(['host_response_rate'	,'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count','latitude','longitude','accommodates','beds','price','minimum_nights','maximum_nights','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','availability_30','availability_60','availability_90','availability_365','number_of_reviews','number_of_reviews_ltm','number_of_reviews_l30d','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','reviews_per_month', "neighborhood_overview"], axis=1)
mexico_cuali
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y= mexico_num
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# <ipython-input-16-2559fb7539ed>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-16-2559fb7539ed>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# Limite superior permitido host_listings_count                              252.830274
# latitude                                          19.532575
# longitude                                        -99.065630
# accommodates                                       9.933140
# ...

# %%
#Encontramos Outliers del Dataframe
outliers= mexico_num[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-17-411d8564f503>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= mexico_num[(y>Limite_Superior)|(y<Limite_Inferior)]
#       neighborhood_overview host_acceptance_rate  host_listings_count  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN                  NaN                  NaN
# ...                     ...                  ...                  ...
# 24219                   NaN                  NaN                  NaN
# 24220                   NaN                  NaN                  NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
mexico2 = mexico_num[(y<=Limite_Superior)&(y>=Limite_Inferior)]
mexico2
# Out:
# <ipython-input-19-b350086dd836>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   mexico2 = mexico_num[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#       neighborhood_overview host_acceptance_rate  host_listings_count  \
# 0                       NaN                  NaN                  3.0
# 1                       NaN                  NaN                  3.0
# 2                       NaN                  NaN                  4.0
# 3                       NaN                  NaN                  1.0
# 4                       NaN                  NaN                 16.0
# ...                     ...                  ...                  ...
# 24219                   NaN                  NaN                  3.0
# 24220                   NaN                  NaN                  1.0
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=mexico_num.isnull().sum()
valores_nulos
# Out:
# neighborhood_overview                           0
# host_acceptance_rate                            0
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=mexico_num.copy()
data_clean=data_clean.fillna(round(mexico_num.mean(),1))
data_clean
# Out:
# <ipython-input-22-0a572b68350d>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clean=data_clean.fillna(round(mexico_num.mean(),1))
#                                    neighborhood_overview host_acceptance_rate  \
# 0                                                      0                   0%
# 1      Located in Coyoacan, in a quiet neighborhood w...                   0%
# 2      This area is called Nuevo Polanco, it has bein...                  90%
# 3      Centro comercial Santa Fe, parque interlomas y...                   0%
# 4                                                      0                  86%
# ...                                                  ...                  ...
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# neighborhood_overview                           0
# host_acceptance_rate                            0
# host_listings_count                             0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# beds                                            0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# availability_30                                 0
# ...

# %%
# Unimos los datas con el dataframe
mex_clean = pd.concat([mexico_cuali,mexico_num], axis=1)
mex_clean
# Out:
#                        id                                      listing_url  \
# 0                 2056638             https://www.airbnb.com/rooms/2056638
# 1                 2072354             https://www.airbnb.com/rooms/2072354
# 2                  696037              https://www.airbnb.com/rooms/696037
# 3                   35797               https://www.airbnb.com/rooms/35797
# 4                   44616               https://www.airbnb.com/rooms/44616
# ...                   ...                                              ...
# 24219  853923589855678923  https://www.airbnb.com/rooms/853923589855678923
# 24220  853966732274073000  https://www.airbnb.com/rooms/853966732274073000
# 24221  854225071295768399  https://www.airbnb.com/rooms/854225071295768399
# 24222  854247693069190865  https://www.airbnb.com/rooms/854247693069190865
# 24223  854260329845513725  https://www.airbnb.com/rooms/854260329845513725
#
#             scrape_id last_scraped       source  \
# ...

# %%
#Convertir DataFrame a CSV
mex_clean.to_csv("Mexico_limpio.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
files.download("Mexico_limpio.csv")
